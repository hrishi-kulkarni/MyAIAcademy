# %% [markdown]
# # Load dataset

# %%
import pandas as pd
url = 'F:\\100DaysOfMLChallenge\\3 Pandas basic tutorial\\train.csv'

df = pd.read_csv(url)
df2 = pd.read_csv('F:\\100DaysOfMLChallenge\\3 Pandas basic tutorial\\test.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Navigating Dataframe

# %%
df.iloc[0]   #Read zeroth row
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.iloc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.set_index(df['Name'], inplace=True)
df.loc['Braund, Mr. Owen Harris']
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: Braund, Mr. Owen Harris, dtype: object

# %% [markdown]
# # Selecting rows based on condition

# %%
# Selecting rows with sex = woman
print(len(df[df['Sex'] == 'female']))
print(len(df))
# Out:
# 314
# 891

# %%
# sex = 'woman' and age > 50
df[(df['Sex'] == 'female') & (df['Age'] > 60)]
# Out:
#                                            PassengerId  Survived  Pclass  \
# Name
# Andrews, Miss. Kornelia Theodosia                  276         1       1
# Turkula, Mrs. (Hedwig)                             484         1       3
# Stone, Mrs. George Nelson (Martha Evelyn)          830         1       1
#
#                                                                                 Name  \
# Name
# Andrews, Miss. Kornelia Theodosia                  Andrews, Miss. Kornelia Theodosia
# Turkula, Mrs. (Hedwig)                                        Turkula, Mrs. (Hedwig)
# Stone, Mrs. George Nelson (Martha Evelyn)  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                                               Sex   Age  SibSp  Parch  Ticket  \
# Name
# Andrews, Miss. Kornelia Theodosia          female  63.0      1      0   13502
# Turkula, Mrs. (Hedwig)                     female  63.0      0      0    4134
# ...

# %% [markdown]
# # Replacing particular value

# %%
# Replace sex 'female' with 'woman'
df['Sex'].replace('female', 'woman', inplace = True)

# %%
df['Sex'].replace('woman', 'female', inplace = True)
df.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Allen, Mr. William Henry                                 3
#
#                                                                                                  Name  \
# Name
# ...

# %%
# Replace multiple values
df['Sex'].replace(['female', 'male'], ['woman', 'man'], inplace = True)
df.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass  \
# Name
# Braund, Mr. Owen Harris                                  3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1
# Heikkinen, Miss. Laina                                   3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1
# Allen, Mr. William Henry                                 3
#
#                                                                                                  Name  \
# Name
# ...

# %%
df.replace('True', 1, inplace=True, regex = True)

# %% [markdown]
# # Rename particular column-names

# %%
df.rename(columns = {'Pclass':'PClass', 'PassengerId':'Id'}, inplace = True)
df.head()
# Out:
#                                                     Id  Survived  PClass  \
# Name
# Braund, Mr. Owen Harris                              1         0       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   2         1       1
# Heikkinen, Miss. Laina                               3         1       3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         4         1       1
# Allen, Mr. William Henry                             5         0       3
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Cumings, Mrs. John Bradley (Florence Briggs Th...
# Heikkinen, Miss. Laina                                                         Heikkinen, Miss. Laina
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %% [markdown]
# # Find min, max, mean, sum, count

# %%
print('Maximum:', df['Age'].max())
print('Minimum:', df['Age'].min())
print('Mean:', df['Age'].mean())
print('Sum:', df['Age'].sum())
print('Count:', df['Age'].count())
# Out:
# Maximum: 80.0
# Minimum: 0.42
# Mean: 29.69911764705882
# Sum: 21205.17
# Count: 714

# %% [markdown]
# # Finding unique values

# %%
df['Sex'].value_counts()
# Out:
# man      577
# woman    314
# Name: Sex, dtype: int64

# %% [markdown]
# # Finding null values

# %%
df[df['Age'].isnull()]
# Out:
#                                                  Id  Survived  PClass  \
# Name
# Moran, Mr. James                                  6         0       3
# Williams, Mr. Charles Eugene                     18         1       2
# Masselmani, Mrs. Fatima                          20         1       3
# Emir, Mr. Farred Chehab                          27         0       3
# O'Dwyer, Miss. Ellen "Nellie"                    29         1       3
# Todoroff, Mr. Lalio                              30         0       3
# Spencer, Mrs. William Augustus (Marie Eugenie)   32         1       1
# Glynn, Miss. Mary Agatha                         33         1       3
# Mamee, Mr. Hanna                                 37         1       3
# Kraeff, Mr. Theodor                              43         0       3
# Rogers, Mr. William John                         46         0       3
# Lennon, Mr. Denis                                47         0       3
# ...

# %% [markdown]
# NaN is borrowed from numpy. So better to convert first into np.nan

# %%
import numpy as np
'''
df['Sex'] = df['Sex'].replace('man', np.nan, inplace = True)
'''

# %%
'''
# To read null values while reading
df = pd.read_csv('+++++', na_values = [np.nan, 'NONE', ''])
'''

# %% [markdown]
# # Dropping column

# %%
df.drop('Age', axis=1)  #Column axis
# Out:
#                                                      Id  Survived  PClass  \
# Name
# Braund, Mr. Owen Harris                               1         0       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...    2         1       1
# Heikkinen, Miss. Laina                                3         1       3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)          4         1       1
# Allen, Mr. William Henry                              5         0       3
# Moran, Mr. James                                      6         0       3
# McCarthy, Mr. Timothy J                               7         0       1
# Palsson, Master. Gosta Leonard                        8         0       3
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     9         1       3
# Nasser, Mrs. Nicholas (Adele Achem)                  10         1       2
# Sandstrom, Miss. Marguerite Rut                      11         1       3
# Bonnell, Miss. Elizabeth                             12         1       1
# ...

# %% [markdown]
# # Grouping rows by value

# %%
df.groupby('Sex').mean()


#Similar to
#SELECT AVG(*)
#FROM table
#GROUPBY ('Sex')
# Out:
#                Id  Survived    PClass        Age     SibSp     Parch  \
# Sex
# man    454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
# woman  431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
#
#             Fare
# Sex
# man    25.523893
# woman  44.479818

# %%
df.groupby('Survived')['Name'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Name, dtype: int64

# %%
df.groupby(['Sex', 'Survived'])['Name'].count()
df.groupby(['Sex', 'Survived'])['Age'].mean()
# Out:
# Sex    Survived
# man    0           31.618056
#        1           27.276022
# woman  0           25.046875
#        1           28.847716
# Name: Age, dtype: float64

# %% [markdown]
# # Iterating over values of particular column

# %%
for name in df['Name'][:10]:
    print(name)
# Out:
# Braund, Mr. Owen Harris
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# Heikkinen, Miss. Laina
# Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Allen, Mr. William Henry
# Moran, Mr. James
# McCarthy, Mr. Timothy J
# Palsson, Master. Gosta Leonard
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Nasser, Mrs. Nicholas (Adele Achem)

# %% [markdown]
# # Applying function over values of particular column

# %%
def trim(x):
    return x.strip()
def uppercase(x):
    return x.upper()
df['Name'] = df['Name'].apply(uppercase)
df.head()
# Out:
#                                                     Id  Survived  PClass  \
# Name
# Braund, Mr. Owen Harris                              1         0       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   2         1       1
# Heikkinen, Miss. Laina                               3         1       3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         4         1       1
# Allen, Mr. William Henry                             5         0       3
#
#                                                                                                  Name  \
# Name
# Braund, Mr. Owen Harris                                                       BRAUND, MR. OWEN HARRIS
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# Heikkinen, Miss. Laina                                                         HEIKKINEN, MISS. LAINA
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# ...

# %% [markdown]
# # Applying function to groups

# %%
df.groupby('Sex').apply(lambda X: X.count())
# Out:
#         Id  Survived  PClass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# man    577       577     577   577  577  453    577    577     577   577
# woman  314       314     314   314  314  261    314    314     314   314
#
#        Cabin  Embarked
# Sex
# man      107       577
# woman     97       312

# %% [markdown]
# # Combining two df

# %%
df_ = df.iloc[:][:]
df2_ = df2.iloc[:][:]
df_['data'] = 'train'
df2_['data'] = 'test'
df_combined = df_.append(df2_)
df_combined
# Out:
# c:\users\hrishi\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# ...

# %%
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
